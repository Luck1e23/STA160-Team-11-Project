# %% [markdown]
# <a href="https://colab.research.google.com/github/Luck1e23/STA160-Team-11-Project/blob/laiq/Newmodel_STA160_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torchxrayvision
# !pip install iterative-stratification
# !pip install validators matplotlib
# Out:
# Requirement already satisfied: torchxrayvision in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Requirement already satisfied: torch>=1 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (0.24.0+cu126)
# Requirement already satisfied: scikit-image>=0.16 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (0.25.2)
# Requirement already satisfied: tqdm>=4 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (4.67.1)
# Requirement already satisfied: numpy>=1 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (2.0.2)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (2.2.2)
# Requirement already satisfied: requests>=1 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (2.32.4)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (11.3.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from torchxrayvision) (2.37.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->torchxrayvision) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->torchxrayvision) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->torchxrayvision) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=1->torchxrayvision) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=1->torchxrayvision) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=1->torchxrayvision) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=1->torchxrayvision) (2025.11.12)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.16->torchxrayvision) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.16->torchxrayvision) (3.6)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.16->torchxrayvision) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.16->torchxrayvision) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.16->torchxrayvision) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1->torchxrayvision) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1->torchxrayvision) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1->torchxrayvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1->torchxrayvision) (3.0.3)
# Requirement already satisfied: iterative-stratification in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->iterative-stratification) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->iterative-stratification) (3.6.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.12/dist-packages (0.35.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# ### Packages

# %%
from PIL import Image
import os
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torch.optim import Adam
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
from pathlib import Path

# Visualization tools
import torchvision
import torchvision.transforms.v2 as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt


# Pre-trained Model: torchxrayvision
import torchxrayvision as xrv
import skimage
from torchvision.models import resnet50, ResNet50_Weights

# %% [markdown]
# ### Pre-Trained Model

# %%
resnet50_model = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_resnet50', pretrained=True)
utils = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_convnets_processing_utils')
# Out:
# Using cache found in /root/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# Using cache found in /root/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub

# %% [markdown]
# ### File Paths

# %%
# Paths
file_path = '/content/drive/Shareddrives/STA_160/dataset/Data_Entry_2017.csv'
train_val = '/content/drive/Shareddrives/STA_160/dataset/train_val_list.txt'
test = '/content/drive/Shareddrives/STA_160/dataset/test_list.txt'
resized_root = '/content/dataset_resized'   # Where resized images will be saved

# %% [markdown]
# ### Creating a 224 x 224 Resized Dataset

# %%
# Old Code for resizing the images before making a dataset class
# Purpose was to speed up the running of the code
'''
# Target Size
IMG_SIZE = (224, 224)

for root, dirs, files in os.walk(dataset_root):
    rel_path = os.path.relpath(root, dataset_root)
    save_dir = os.path.join(resized_root, rel_path)
    os.makedirs(save_dir, exist_ok=True)

    for f in files:
        if f.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(root, f)

            # Load and convert to grayscale (preserve pixel values)
            img = Image.open(img_path).convert("L")
            arr = np.array(img).astype(np.uint8)

            # Resize using bilinear interpolation
            img_resized = Image.fromarray(arr).resize(IMG_SIZE, Image.BILINEAR)

            # Build output filename (always PNG)
            base = os.path.splitext(f)[0]
            out_path = os.path.join(save_dir, base + ".png")

            # Save as PNG to avoid JPEG compression artifacts
            img_resized.save(out_path, format="PNG")

# Zip the resized dataset
# !zip -r -q /content/NIH_resized.zip /content/dataset_resized

# Copy and upload to the shared drive
# !cp /content/NIH_resized.zip /content/drive/Shareddrives/STA_160/
'''
# Out:
# '\n# Target Size\nIMG_SIZE = (224, 224)\n\nfor root, dirs, files in os.walk(dataset_root):\n    rel_path = os.path.relpath(root, dataset_root)\n    save_dir = os.path.join(resized_root, rel_path)\n    os.makedirs(save_dir, exist_ok=True)\n\n    for f in files:\n        if f.lower().endswith((\'.png\', \'.jpg\', \'.jpeg\')):\n            img_path = os.path.join(root, f)\n\n            # Load and convert to grayscale (preserve pixel values)\n            img = Image.open(img_path).convert("L")\n            arr = np.array(img).astype(np.uint8)\n\n            # Resize using bilinear interpolation\n            img_resized = Image.fromarray(arr).resize(IMG_SIZE, Image.BILINEAR)\n\n            # Build output filename (always PNG)\n            base = os.path.splitext(f)[0]\n            out_path = os.path.join(save_dir, base + ".png")\n\n            # Save as PNG to avoid JPEG compression artifacts\n            img_resized.save(out_path, format="PNG")\n\n# Zip the resized dataset\n!zip -r -q /content/NIH_resized.zip /content/dataset_resized\n\n# Copy and upload to the shared drive\n!cp /content/NIH_resized.zip /content/drive/Shareddrives/STA_160/\n'

# %%
# Unzipping the resized dataset from shared drives
# !unzip -q /content/drive/Shareddrives/STA_160/NIH_resized.zip -d /content/dataset

# !mkdir -p /content/dataset_resized
# Finds all image files inside subfolders
# !find /content/dataset/content/dataset_resized/ -type f -exec mv -t /content/dataset_resized/ {} +
# !rm -rf /content/dataset/content #remove folder

# %% [markdown]
# ### Dataset

# %%
# Dataset Class
class NIHXrays(Dataset):
    def __init__(self, file_path, dataset_root, list_file=None, transform=None):
        self.data = pd.read_csv(file_path)
        self.dataset_root = dataset_root
        self.transform = transform

        # Optional filtering
        if list_file:
            with open(list_file, 'r') as f:
                image_list = {line.strip() for line in f.readlines()}
            self.data = self.data[self.data['Image Index'].isin(image_list)].reset_index(drop=True)

        # Create label map
        all_labels = set()
        for labels in self.data['Finding Labels']:
            for l in labels.split('|'):
                all_labels.add(l.strip())

        self.all_labels = sorted(all_labels)
        self.label_map = {label: i for i, label in enumerate(self.all_labels)}

        # Build multi-hot label vectors
        self.finding_labels = []
        for labels in self.data['Finding Labels']:
            vec = torch.zeros(len(self.all_labels))
            for l in labels.split('|'):
                if l.strip() in self.label_map:
                    vec[self.label_map[l.strip()]] = 1.0
            self.finding_labels.append(vec)

        self.finding_labels = torch.stack(self.finding_labels).float()

        # Recursively map image filenames to full paths
        self.image_map = {}
        for img_path in Path(dataset_root).rglob("*.png"):
            self.image_map[img_path.name] = str(img_path)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name = self.data.iloc[idx]['Image Index']

        if img_name not in self.image_map:
            raise FileNotFoundError(f"Image {img_name} not found.")

        # Load Image
        img = Image.open(self.image_map[img_name]).convert("L")

        if self.transform is not None:
          img = self.transform(img)

        img = np.array(img).astype(np.float32) # PIL image --> NumPy [224,224]

        # XRV normalizaiton
        img = xrv.datasets.normalize(img, maxval=255)

        #   NumPy --> Tensor
        img = torch.from_numpy(img).unsqueeze(0) # [1, 224, 224]

        label = self.finding_labels[idx].float()

        return img, label, img_name

# %%
# Data Augmentation
rand_transforms = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip()
])

train_val_data = NIHXrays(file_path, resized_root, list_file=train_val, transform=rand_transforms)
test_data      = NIHXrays(file_path, resized_root, list_file=test, transform=None)

# %% [markdown]
# ### Multi-Label Stratified Split for Training and Validation

# %%
# Convert labels to NumPy for the stratifier
y = train_val_data.finding_labels.numpy()   # shape: [N, C]
X = np.arange(len(train_val_data))          # dummy feature array

#Stratified Splitting
msss = MultilabelStratifiedShuffleSplit(
    n_splits=1,
    test_size=0.2,
    random_state=42
)
#only want the first split & get train and validation indices
train_idx, valid_idx = next(msss.split(X, y))

# Get train and validation datasets based on the indices
train_data = Subset(train_val_data, train_idx)
valid_data = Subset(train_val_data, valid_idx)

# %% [markdown]
# ### Data Augmentation and Data Loader

# %%
# Create DataLoaders for training and validation
n = 32
train_loader = DataLoader(train_data, batch_size=n, shuffle=True, num_workers=2, pin_memory=True)
train_N = len(train_loader.dataset)
valid_loader = DataLoader(valid_data, batch_size=n, num_workers=2, pin_memory=True)
valid_N = len(valid_loader.dataset)

# %% [markdown]
# ### Freezing Base Layers of Pre-Trained Model

# %%
# XRV pathologies
xrv_labels = ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax',
              'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia',
              'Pleural_Thickening', 'Cardiomegaly', 'Nodule', 'Mass', 'Hernia',
              '', '', '', '']

# NIHXray Labels
dataset_labels = train_val_data.all_labels
print("Using label order:", dataset_labels)

# Create mapping from dataset_labels → xrv_labels index
xrv_index_map = [xrv_labels.index(lbl) if lbl in xrv_labels else None for lbl in dataset_labels]


class XRV_Finetune(nn.Module):
    def __init__(self, base_model, num_classes, xrv_index_map, no_finding_index):
        super().__init__()
        self.base = base_model
        self.xrv_index_map = xrv_index_map
        self.no_finding_index = no_finding_index

        # DenseNet outputs 18 XRV logits → project them to 15 classes
        self.feature_dim = len(xrv_index_map)

        # Add a learnable embedding vector for "No Finding"
        self.no_finding_emb = nn.Parameter(torch.zeros(1))

        # Classification head
        self.classifier = nn.Linear(self.feature_dim, num_classes)

    def forward(self, x):
        out = self.base(x)  # [B, 18]

        features = []
        for idx in self.xrv_index_map:
            if idx is not None:
                features.append(out[:, idx].unsqueeze(1))
            else:
                # Use learnable embedding
                emb = self.no_finding_emb.expand(out.size(0), 1)
                features.append(emb)

        features = torch.cat(features, dim=1)
        out = self.classifier(features)
        return out

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#Pre-trained Model
xrv_model = xrv.models.DenseNet(weights="densenet121-res224-nih")

# Freeze
xrv_model.requires_grad_(False)
print("XRV frozen")


N_CLASSES = 15
no_finding_index = 14

my_model = XRV_Finetune(xrv_model, N_CLASSES, xrv_index_map = xrv_index_map, no_finding_index = no_finding_index).to(device)
# Out:
# Using label order: ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Effusion', 'Emphysema', 'Fibrosis', 'Hernia', 'Infiltration', 'Mass', 'No Finding', 'Nodule', 'Pleural_Thickening', 'Pneumonia', 'Pneumothorax']
# XRV frozen

# %%
#Load saved model
best_model_path = "/content/drive/Shareddrives/STA_160/nih_densenet121_finetuned_best.pth"

state_dict = torch.load(best_model_path, map_location=device)
my_model.load_state_dict(state_dict)
my_model.eval()

print("Loaded fine-tuned model from:", best_model_path)
print("Classifier weight mean:", my_model.classifier.weight.mean().item())
print("Classifier bias mean:", my_model.classifier.bias.mean().item())
print("Classifier weight std:", my_model.classifier.weight.std().item())
# Out:
# Loaded fine-tuned model from: /content/drive/Shareddrives/STA_160/nih_densenet121_finetuned_best.pth
# Classifier weight mean: 0.09434664994478226
# Classifier bias mean: -0.7427027225494385
# Classifier weight std: 0.34683993458747864

# %% [markdown]
# ### Loss Function and Optimizer

# %%
# Finding class weights
def compute_pos_weights(subset):

    # Get all labels that are in the subset
    full_dataset = subset.dataset
    labels = full_dataset.finding_labels[subset.indices].numpy()

    pos_counts = labels.sum(axis = 0) #counts how many of each disease present in the dataset
    neg_counts = (labels == 0).sum(axis = 0) # counts how many times each disease was NOT present in the dataset
    pos_weight = neg_counts / (pos_counts + 1e-6) # Ratio of negatives to positives. 1e-6 to prevent dividing by 0.

    return torch.tensor(pos_weight, dtype = torch.float32) #Convert to tensor

pos_weight = compute_pos_weights(train_data).to(device) # Addressing class imbalance: add more weight to rare diseases
pos_weight = torch.clamp(pos_weight, max=30) # Because one of the values was > 600

# Using Focal Loss as loss function
class Focal_Loss(nn.Module):
    def __init__(self, gamma=2.0, pos_weight=None):
        super().__init__()
        self.gamma = gamma
        self .pos_weight = pos_weight

    def forward(self, logits, targets):
        # logits: (B, C)
        # targets: (B, C)

        # 1. Compute BCE with logits, elementwise (NO reduction)
        bce = F.binary_cross_entropy_with_logits(
            logits,
            targets,
            pos_weight=self.pos_weight,
            reduction='none'
        )

        # 2. Compute p_t = sigmoid(logits) for focal term
        probs = torch.sigmoid(logits)
        p_t = probs * targets + (1 - probs) * (1 - targets)

        # 3. Apply focal modulation
        focal_factor = (1 - p_t) ** self.gamma

        # 4. Combine
        loss = focal_factor * bce

        # 5. Reduce mean
        return loss.mean()

loss_function = Focal_Loss(gamma=2.0, pos_weight=pos_weight)

optimizer = Adam(my_model.classifier.parameters(), lr=1e-3) #increase classifiers learning rate
my_model = my_model.to(device)

# %% [markdown]
# ### Model Performance Metrics

# %%
from sklearn.metrics import f1_score, roc_auc_score, precision_recall_curve
import torch

def pr_curve_thresholds(y_true, y_prob, min_thresh=0.1):
    num_labels = y_true.shape[1]
    thresholds = np.zeros(num_labels)

    for i in range(num_labels):
        p, r, t = precision_recall_curve(y_true[:, i], y_prob[:, i])
        f1 = 2 * p * r / (p + r + 1e-9)

        if len(t) == 0:
            thresholds[i] = min_thresh  # Ensure thresholds are not all zero
        else:
            thresholds[i] = t[np.argmax(f1)]

    return thresholds

def compute_f1(y_true, y_prob, thresholds):

    y_true = y_true.cpu()
    y_prob = y_prob.cpu()

    # Converts thresholds into tensors and match the shape of y_prob
    thresholds = torch.tensor(thresholds, dtype = y_prob.dtype)
    y_pred = (y_prob >= thresholds.unsqueeze(0)).int()

    return f1_score(y_true, y_pred, average="macro", zero_division=0)

def compute_auc(y_true, y_prob):

    y_true = y_true.detach().cpu().numpy() #binary labels
    y_prob = y_prob.detach().cpu().numpy() #sigmoid probabilities

    return roc_auc_score(y_true, y_prob, average = "macro")

# %% [markdown]
# ### Training and Validation Functions

# %%
# def train(model, train_loader, optimizer, loss_fn, device, check_grad=False):
#     model.train()

#     total_loss = 0
#     all_probs = []
#     all_labels = []

#     for imgs, labels, _ in train_loader:

#         imgs = imgs.to(device)
#         labels = labels.to(device)

#         # Forward
#         outputs = model(imgs)

#         # Compute loss
#         batch_loss = loss_fn(outputs, labels)

#         # Backprop
#         optimizer.zero_grad()
#         batch_loss.backward()
#         optimizer.step()

#         total_loss += batch_loss.item()

#         # Probability for AUC
#         probs = torch.sigmoid(outputs)

#         all_probs.append(probs.detach().cpu())
#         all_labels.append(labels.detach().cpu())

#     if check_grad:
#         print("Last Gradient:")
#         for p in model.parameters():
#             if p.grad is not None:
#                 print(p.grad)

#     # Compute AUROC at end of epoch
#     all_probs = torch.cat(all_probs)
#     all_labels = torch.cat(all_labels)

#     auc = compute_auc(all_labels, all_probs)
#     epoch_loss = total_loss / len(train_loader)

#     print("Train - Loss: {:.4f}, AUC: {:.4f}".format(epoch_loss, auc))

#     return epoch_loss, auc

# def validate(model, valid_loader, loss_fn, device):
#     model.eval()

#     total_loss = 0
#     all_probs = []
#     all_labels = []

#     with torch.no_grad():
#         for imgs, labels, _ in valid_loader:
#             imgs = imgs.to(device)
#             labels = labels.to(device)

#             # Compute loss
#             outputs = model(imgs)
#             batch_loss = loss_fn(outputs, labels)

#             total_loss += batch_loss.item()

#             # Get probabilities for F1 and AUC
#             probs = torch.sigmoid(outputs)

#             all_probs.append(probs.detach().cpu())
#             all_labels.append(labels.detach().cpu())

#     #Store all probabilities and labels
#     all_probs = torch.cat(all_probs)
#     all_labels = torch.cat(all_labels)

#     # Compute loss for every epoch
#     epoch_loss = total_loss / len(valid_loader)

#     return epoch_loss, all_probs, all_labels

# %% [markdown]
# ### Fit Model and Evaluations

# %%
# epochs = 5

# for epoch in range(epochs):
#     print(f"\nEpoch {epoch+1}")

#     train_loss, train_auc = train(
#         model=my_model,
#         train_loader=train_loader,
#         optimizer=optimizer,
#         loss_fn=loss_function,
#         device=device,
#         check_grad=False
#     )

#     valid_loss, valid_probs, valid_labels = validate(
#         model=my_model,
#         valid_loader=valid_loader,
#         loss_fn=loss_function,
#         device=device
#     )

#     #Find thresholds per label from validation
#     thresholds = pr_curve_thresholds(valid_labels, valid_probs)

#     # Find F1 and AUC for validation
#     valid_f1 = compute_f1(valid_labels, valid_probs, thresholds)
#     valid_auc = compute_auc(valid_labels, valid_probs)

#     print("Valid - Loss: {:.4f}, F1: {:.4f}, AUC: {:.4f}".format(valid_loss, valid_f1, valid_auc))

# %% [markdown]
# ### Fine-Tuning Model

# %%
# # Fine Tuning the model

# # Unfreeze the last block model
# for name, param in my_model.base.features.named_parameters():
#     if "denseblock4" in name or "transition3" in name or "norm5" in name:
#         param.requires_grad = True

# #Assign different learning rates
# optimizer = Adam([
#     {'params': [p for p in my_model.base.parameters() if p.requires_grad], 'lr': 1e-6},
#     {'params': my_model.classifier.parameters(), 'lr': 1e-3}
# ])

# %%
# epochs = 30


# for epoch in range(epochs):
#     print(f"\nEpoch {epoch+1}")

#     train_loss, train_auc = train(
#         model=my_model,
#         train_loader=train_loader,
#         optimizer=optimizer,
#         loss_fn=loss_function,
#         device=device,
#         check_grad=False
#     )

#     valid_loss, valid_probs, valid_labels = validate(
#         model=my_model,
#         valid_loader=valid_loader,
#         loss_fn=loss_function,
#         device=device
#     )

#     #Find thresholds per label from validation
#     thresholds = pr_curve_thresholds(valid_labels, valid_probs)

#     # Find F1 and AUC for validation
#     valid_f1 = compute_f1(valid_labels, valid_probs, thresholds)
#     valid_auc = compute_auc(valid_labels, valid_probs)

#     print("Valid - Loss: {:.4f}, F1: {:.4f}, AUC: {:.4f}".format(valid_loss, valid_f1, valid_auc))

# %%
for name, param in my_model.named_parameters():
    print(f"{name:60}  trainable={param.requires_grad}")
# Out:
# no_finding_emb                                                trainable=True
# base.features.conv0.weight                                    trainable=False
# base.features.norm0.weight                                    trainable=False
# base.features.norm0.bias                                      trainable=False
# base.features.denseblock1.denselayer1.norm1.weight            trainable=False
# base.features.denseblock1.denselayer1.norm1.bias              trainable=False
# base.features.denseblock1.denselayer1.conv1.weight            trainable=False
# base.features.denseblock1.denselayer1.norm2.weight            trainable=False
# base.features.denseblock1.denselayer1.norm2.bias              trainable=False
# base.features.denseblock1.denselayer1.conv2.weight            trainable=False
# base.features.denseblock1.denselayer2.norm1.weight            trainable=False
# base.features.denseblock1.denselayer2.norm1.bias              trainable=False
# base.features.denseblock1.denselayer2.conv1.weight            trainable=False
# base.features.denseblock1.denselayer2.norm2.weight            trainable=False
# base.features.denseblock1.denselayer2.norm2.bias              trainable=False
# base.features.denseblock1.denselayer2.conv2.weight            trainable=False
# base.features.denseblock1.denselayer3.norm1.weight            trainable=False
# base.features.denseblock1.denselayer3.norm1.bias              trainable=False
# base.features.denseblock1.denselayer3.conv1.weight            trainable=False
# base.features.denseblock1.denselayer3.norm2.weight            trainable=False
# base.features.denseblock1.denselayer3.norm2.bias              trainable=False
# base.features.denseblock1.denselayer3.conv2.weight            trainable=False
# base.features.denseblock1.denselayer4.norm1.weight            trainable=False
# base.features.denseblock1.denselayer4.norm1.bias              trainable=False
# base.features.denseblock1.denselayer4.conv1.weight            trainable=False
# base.features.denseblock1.denselayer4.norm2.weight            trainable=False
# base.features.denseblock1.denselayer4.norm2.bias              trainable=False
# base.features.denseblock1.denselayer4.conv2.weight            trainable=False
# base.features.denseblock1.denselayer5.norm1.weight            trainable=False
# base.features.denseblock1.denselayer5.norm1.bias              trainable=False
# base.features.denseblock1.denselayer5.conv1.weight            trainable=False
# base.features.denseblock1.denselayer5.norm2.weight            trainable=False
# base.features.denseblock1.denselayer5.norm2.bias              trainable=False
# base.features.denseblock1.denselayer5.conv2.weight            trainable=False
# base.features.denseblock1.denselayer6.norm1.weight            trainable=False
# base.features.denseblock1.denselayer6.norm1.bias              trainable=False
# base.features.denseblock1.denselayer6.conv1.weight            trainable=False
# base.features.denseblock1.denselayer6.norm2.weight            trainable=False
# base.features.denseblock1.denselayer6.norm2.bias              trainable=False
# base.features.denseblock1.denselayer6.conv2.weight            trainable=False
# base.features.transition1.norm.weight                         trainable=False
# base.features.transition1.norm.bias                           trainable=False
# base.features.transition1.conv.weight                         trainable=False
# base.features.denseblock2.denselayer1.norm1.weight            trainable=False
# base.features.denseblock2.denselayer1.norm1.bias              trainable=False
# base.features.denseblock2.denselayer1.conv1.weight            trainable=False
# base.features.denseblock2.denselayer1.norm2.weight            trainable=False
# base.features.denseblock2.denselayer1.norm2.bias              trainable=False
# base.features.denseblock2.denselayer1.conv2.weight            trainable=False
# base.features.denseblock2.denselayer2.norm1.weight            trainable=False
# base.features.denseblock2.denselayer2.norm1.bias              trainable=False
# base.features.denseblock2.denselayer2.conv1.weight            trainable=False
# base.features.denseblock2.denselayer2.norm2.weight            trainable=False
# base.features.denseblock2.denselayer2.norm2.bias              trainable=False
# base.features.denseblock2.denselayer2.conv2.weight            trainable=False
# base.features.denseblock2.denselayer3.norm1.weight            trainable=False
# base.features.denseblock2.denselayer3.norm1.bias              trainable=False
# base.features.denseblock2.denselayer3.conv1.weight            trainable=False
# base.features.denseblock2.denselayer3.norm2.weight            trainable=False
# base.features.denseblock2.denselayer3.norm2.bias              trainable=False
# base.features.denseblock2.denselayer3.conv2.weight            trainable=False
# base.features.denseblock2.denselayer4.norm1.weight            trainable=False
# base.features.denseblock2.denselayer4.norm1.bias              trainable=False
# base.features.denseblock2.denselayer4.conv1.weight            trainable=False
# base.features.denseblock2.denselayer4.norm2.weight            trainable=False
# base.features.denseblock2.denselayer4.norm2.bias              trainable=False
# base.features.denseblock2.denselayer4.conv2.weight            trainable=False
# base.features.denseblock2.denselayer5.norm1.weight            trainable=False
# base.features.denseblock2.denselayer5.norm1.bias              trainable=False
# base.features.denseblock2.denselayer5.conv1.weight            trainable=False
# base.features.denseblock2.denselayer5.norm2.weight            trainable=False
# base.features.denseblock2.denselayer5.norm2.bias              trainable=False
# base.features.denseblock2.denselayer5.conv2.weight            trainable=False
# base.features.denseblock2.denselayer6.norm1.weight            trainable=False
# base.features.denseblock2.denselayer6.norm1.bias              trainable=False
# base.features.denseblock2.denselayer6.conv1.weight            trainable=False
# base.features.denseblock2.denselayer6.norm2.weight            trainable=False
# base.features.denseblock2.denselayer6.norm2.bias              trainable=False
# base.features.denseblock2.denselayer6.conv2.weight            trainable=False
# base.features.denseblock2.denselayer7.norm1.weight            trainable=False
# base.features.denseblock2.denselayer7.norm1.bias              trainable=False
# base.features.denseblock2.denselayer7.conv1.weight            trainable=False
# base.features.denseblock2.denselayer7.norm2.weight            trainable=False
# base.features.denseblock2.denselayer7.norm2.bias              trainable=False
# base.features.denseblock2.denselayer7.conv2.weight            trainable=False
# base.features.denseblock2.denselayer8.norm1.weight            trainable=False
# base.features.denseblock2.denselayer8.norm1.bias              trainable=False
# base.features.denseblock2.denselayer8.conv1.weight            trainable=False
# base.features.denseblock2.denselayer8.norm2.weight            trainable=False
# base.features.denseblock2.denselayer8.norm2.bias              trainable=False
# base.features.denseblock2.denselayer8.conv2.weight            trainable=False
# base.features.denseblock2.denselayer9.norm1.weight            trainable=False
# base.features.denseblock2.denselayer9.norm1.bias              trainable=False
# base.features.denseblock2.denselayer9.conv1.weight            trainable=False
# base.features.denseblock2.denselayer9.norm2.weight            trainable=False
# base.features.denseblock2.denselayer9.norm2.bias              trainable=False
# base.features.denseblock2.denselayer9.conv2.weight            trainable=False
# base.features.denseblock2.denselayer10.norm1.weight           trainable=False
# base.features.denseblock2.denselayer10.norm1.bias             trainable=False
# base.features.denseblock2.denselayer10.conv1.weight           trainable=False
# base.features.denseblock2.denselayer10.norm2.weight           trainable=False
# base.features.denseblock2.denselayer10.norm2.bias             trainable=False
# base.features.denseblock2.denselayer10.conv2.weight           trainable=False
# base.features.denseblock2.denselayer11.norm1.weight           trainable=False
# base.features.denseblock2.denselayer11.norm1.bias             trainable=False
# base.features.denseblock2.denselayer11.conv1.weight           trainable=False
# base.features.denseblock2.denselayer11.norm2.weight           trainable=False
# base.features.denseblock2.denselayer11.norm2.bias             trainable=False
# base.features.denseblock2.denselayer11.conv2.weight           trainable=False
# base.features.denseblock2.denselayer12.norm1.weight           trainable=False
# base.features.denseblock2.denselayer12.norm1.bias             trainable=False
# base.features.denseblock2.denselayer12.conv1.weight           trainable=False
# base.features.denseblock2.denselayer12.norm2.weight           trainable=False
# base.features.denseblock2.denselayer12.norm2.bias             trainable=False
# base.features.denseblock2.denselayer12.conv2.weight           trainable=False
# base.features.transition2.norm.weight                         trainable=False
# base.features.transition2.norm.bias                           trainable=False
# base.features.transition2.conv.weight                         trainable=False
# base.features.denseblock3.denselayer1.norm1.weight            trainable=False
# base.features.denseblock3.denselayer1.norm1.bias              trainable=False
# base.features.denseblock3.denselayer1.conv1.weight            trainable=False
# base.features.denseblock3.denselayer1.norm2.weight            trainable=False
# base.features.denseblock3.denselayer1.norm2.bias              trainable=False
# base.features.denseblock3.denselayer1.conv2.weight            trainable=False
# base.features.denseblock3.denselayer2.norm1.weight            trainable=False
# base.features.denseblock3.denselayer2.norm1.bias              trainable=False
# base.features.denseblock3.denselayer2.conv1.weight            trainable=False
# base.features.denseblock3.denselayer2.norm2.weight            trainable=False
# base.features.denseblock3.denselayer2.norm2.bias              trainable=False
# base.features.denseblock3.denselayer2.conv2.weight            trainable=False
# base.features.denseblock3.denselayer3.norm1.weight            trainable=False
# base.features.denseblock3.denselayer3.norm1.bias              trainable=False
# base.features.denseblock3.denselayer3.conv1.weight            trainable=False
# base.features.denseblock3.denselayer3.norm2.weight            trainable=False
# base.features.denseblock3.denselayer3.norm2.bias              trainable=False
# base.features.denseblock3.denselayer3.conv2.weight            trainable=False
# base.features.denseblock3.denselayer4.norm1.weight            trainable=False
# base.features.denseblock3.denselayer4.norm1.bias              trainable=False
# base.features.denseblock3.denselayer4.conv1.weight            trainable=False
# base.features.denseblock3.denselayer4.norm2.weight            trainable=False
# base.features.denseblock3.denselayer4.norm2.bias              trainable=False
# base.features.denseblock3.denselayer4.conv2.weight            trainable=False
# base.features.denseblock3.denselayer5.norm1.weight            trainable=False
# base.features.denseblock3.denselayer5.norm1.bias              trainable=False
# base.features.denseblock3.denselayer5.conv1.weight            trainable=False
# base.features.denseblock3.denselayer5.norm2.weight            trainable=False
# base.features.denseblock3.denselayer5.norm2.bias              trainable=False
# base.features.denseblock3.denselayer5.conv2.weight            trainable=False
# base.features.denseblock3.denselayer6.norm1.weight            trainable=False
# base.features.denseblock3.denselayer6.norm1.bias              trainable=False
# base.features.denseblock3.denselayer6.conv1.weight            trainable=False
# base.features.denseblock3.denselayer6.norm2.weight            trainable=False
# base.features.denseblock3.denselayer6.norm2.bias              trainable=False
# base.features.denseblock3.denselayer6.conv2.weight            trainable=False
# base.features.denseblock3.denselayer7.norm1.weight            trainable=False
# base.features.denseblock3.denselayer7.norm1.bias              trainable=False
# base.features.denseblock3.denselayer7.conv1.weight            trainable=False
# base.features.denseblock3.denselayer7.norm2.weight            trainable=False
# base.features.denseblock3.denselayer7.norm2.bias              trainable=False
# base.features.denseblock3.denselayer7.conv2.weight            trainable=False
# base.features.denseblock3.denselayer8.norm1.weight            trainable=False
# base.features.denseblock3.denselayer8.norm1.bias              trainable=False
# base.features.denseblock3.denselayer8.conv1.weight            trainable=False
# base.features.denseblock3.denselayer8.norm2.weight            trainable=False
# base.features.denseblock3.denselayer8.norm2.bias              trainable=False
# base.features.denseblock3.denselayer8.conv2.weight            trainable=False
# base.features.denseblock3.denselayer9.norm1.weight            trainable=False
# base.features.denseblock3.denselayer9.norm1.bias              trainable=False
# base.features.denseblock3.denselayer9.conv1.weight            trainable=False
# base.features.denseblock3.denselayer9.norm2.weight            trainable=False
# base.features.denseblock3.denselayer9.norm2.bias              trainable=False
# base.features.denseblock3.denselayer9.conv2.weight            trainable=False
# base.features.denseblock3.denselayer10.norm1.weight           trainable=False
# base.features.denseblock3.denselayer10.norm1.bias             trainable=False
# base.features.denseblock3.denselayer10.conv1.weight           trainable=False
# base.features.denseblock3.denselayer10.norm2.weight           trainable=False
# base.features.denseblock3.denselayer10.norm2.bias             trainable=False
# base.features.denseblock3.denselayer10.conv2.weight           trainable=False
# base.features.denseblock3.denselayer11.norm1.weight           trainable=False
# base.features.denseblock3.denselayer11.norm1.bias             trainable=False
# base.features.denseblock3.denselayer11.conv1.weight           trainable=False
# base.features.denseblock3.denselayer11.norm2.weight           trainable=False
# base.features.denseblock3.denselayer11.norm2.bias             trainable=False
# base.features.denseblock3.denselayer11.conv2.weight           trainable=False
# base.features.denseblock3.denselayer12.norm1.weight           trainable=False
# base.features.denseblock3.denselayer12.norm1.bias             trainable=False
# base.features.denseblock3.denselayer12.conv1.weight           trainable=False
# base.features.denseblock3.denselayer12.norm2.weight           trainable=False
# base.features.denseblock3.denselayer12.norm2.bias             trainable=False
# base.features.denseblock3.denselayer12.conv2.weight           trainable=False
# base.features.denseblock3.denselayer13.norm1.weight           trainable=False
# base.features.denseblock3.denselayer13.norm1.bias             trainable=False
# base.features.denseblock3.denselayer13.conv1.weight           trainable=False
# base.features.denseblock3.denselayer13.norm2.weight           trainable=False
# base.features.denseblock3.denselayer13.norm2.bias             trainable=False
# base.features.denseblock3.denselayer13.conv2.weight           trainable=False
# base.features.denseblock3.denselayer14.norm1.weight           trainable=False
# base.features.denseblock3.denselayer14.norm1.bias             trainable=False
# base.features.denseblock3.denselayer14.conv1.weight           trainable=False
# base.features.denseblock3.denselayer14.norm2.weight           trainable=False
# base.features.denseblock3.denselayer14.norm2.bias             trainable=False
# base.features.denseblock3.denselayer14.conv2.weight           trainable=False
# base.features.denseblock3.denselayer15.norm1.weight           trainable=False
# base.features.denseblock3.denselayer15.norm1.bias             trainable=False
# base.features.denseblock3.denselayer15.conv1.weight           trainable=False
# base.features.denseblock3.denselayer15.norm2.weight           trainable=False
# base.features.denseblock3.denselayer15.norm2.bias             trainable=False
# base.features.denseblock3.denselayer15.conv2.weight           trainable=False
# base.features.denseblock3.denselayer16.norm1.weight           trainable=False
# base.features.denseblock3.denselayer16.norm1.bias             trainable=False
# base.features.denseblock3.denselayer16.conv1.weight           trainable=False
# base.features.denseblock3.denselayer16.norm2.weight           trainable=False
# base.features.denseblock3.denselayer16.norm2.bias             trainable=False
# base.features.denseblock3.denselayer16.conv2.weight           trainable=False
# base.features.denseblock3.denselayer17.norm1.weight           trainable=False
# base.features.denseblock3.denselayer17.norm1.bias             trainable=False
# base.features.denseblock3.denselayer17.conv1.weight           trainable=False
# base.features.denseblock3.denselayer17.norm2.weight           trainable=False
# base.features.denseblock3.denselayer17.norm2.bias             trainable=False
# base.features.denseblock3.denselayer17.conv2.weight           trainable=False
# base.features.denseblock3.denselayer18.norm1.weight           trainable=False
# base.features.denseblock3.denselayer18.norm1.bias             trainable=False
# base.features.denseblock3.denselayer18.conv1.weight           trainable=False
# base.features.denseblock3.denselayer18.norm2.weight           trainable=False
# base.features.denseblock3.denselayer18.norm2.bias             trainable=False
# base.features.denseblock3.denselayer18.conv2.weight           trainable=False
# base.features.denseblock3.denselayer19.norm1.weight           trainable=False
# base.features.denseblock3.denselayer19.norm1.bias             trainable=False
# base.features.denseblock3.denselayer19.conv1.weight           trainable=False
# base.features.denseblock3.denselayer19.norm2.weight           trainable=False
# base.features.denseblock3.denselayer19.norm2.bias             trainable=False
# base.features.denseblock3.denselayer19.conv2.weight           trainable=False
# base.features.denseblock3.denselayer20.norm1.weight           trainable=False
# base.features.denseblock3.denselayer20.norm1.bias             trainable=False
# base.features.denseblock3.denselayer20.conv1.weight           trainable=False
# base.features.denseblock3.denselayer20.norm2.weight           trainable=False
# base.features.denseblock3.denselayer20.norm2.bias             trainable=False
# base.features.denseblock3.denselayer20.conv2.weight           trainable=False
# base.features.denseblock3.denselayer21.norm1.weight           trainable=False
# base.features.denseblock3.denselayer21.norm1.bias             trainable=False
# base.features.denseblock3.denselayer21.conv1.weight           trainable=False
# base.features.denseblock3.denselayer21.norm2.weight           trainable=False
# base.features.denseblock3.denselayer21.norm2.bias             trainable=False
# base.features.denseblock3.denselayer21.conv2.weight           trainable=False
# base.features.denseblock3.denselayer22.norm1.weight           trainable=False
# base.features.denseblock3.denselayer22.norm1.bias             trainable=False
# base.features.denseblock3.denselayer22.conv1.weight           trainable=False
# base.features.denseblock3.denselayer22.norm2.weight           trainable=False
# base.features.denseblock3.denselayer22.norm2.bias             trainable=False
# base.features.denseblock3.denselayer22.conv2.weight           trainable=False
# base.features.denseblock3.denselayer23.norm1.weight           trainable=False
# base.features.denseblock3.denselayer23.norm1.bias             trainable=False
# base.features.denseblock3.denselayer23.conv1.weight           trainable=False
# base.features.denseblock3.denselayer23.norm2.weight           trainable=False
# base.features.denseblock3.denselayer23.norm2.bias             trainable=False
# base.features.denseblock3.denselayer23.conv2.weight           trainable=False
# base.features.denseblock3.denselayer24.norm1.weight           trainable=False
# base.features.denseblock3.denselayer24.norm1.bias             trainable=False
# base.features.denseblock3.denselayer24.conv1.weight           trainable=False
# base.features.denseblock3.denselayer24.norm2.weight           trainable=False
# base.features.denseblock3.denselayer24.norm2.bias             trainable=False
# base.features.denseblock3.denselayer24.conv2.weight           trainable=False
# base.features.transition3.norm.weight                         trainable=False
# base.features.transition3.norm.bias                           trainable=False
# base.features.transition3.conv.weight                         trainable=False
# base.features.denseblock4.denselayer1.norm1.weight            trainable=False
# base.features.denseblock4.denselayer1.norm1.bias              trainable=False
# base.features.denseblock4.denselayer1.conv1.weight            trainable=False
# base.features.denseblock4.denselayer1.norm2.weight            trainable=False
# base.features.denseblock4.denselayer1.norm2.bias              trainable=False
# base.features.denseblock4.denselayer1.conv2.weight            trainable=False
# base.features.denseblock4.denselayer2.norm1.weight            trainable=False
# base.features.denseblock4.denselayer2.norm1.bias              trainable=False
# base.features.denseblock4.denselayer2.conv1.weight            trainable=False
# base.features.denseblock4.denselayer2.norm2.weight            trainable=False
# base.features.denseblock4.denselayer2.norm2.bias              trainable=False
# base.features.denseblock4.denselayer2.conv2.weight            trainable=False
# base.features.denseblock4.denselayer3.norm1.weight            trainable=False
# base.features.denseblock4.denselayer3.norm1.bias              trainable=False
# base.features.denseblock4.denselayer3.conv1.weight            trainable=False
# base.features.denseblock4.denselayer3.norm2.weight            trainable=False
# base.features.denseblock4.denselayer3.norm2.bias              trainable=False
# base.features.denseblock4.denselayer3.conv2.weight            trainable=False
# base.features.denseblock4.denselayer4.norm1.weight            trainable=False
# base.features.denseblock4.denselayer4.norm1.bias              trainable=False
# base.features.denseblock4.denselayer4.conv1.weight            trainable=False
# base.features.denseblock4.denselayer4.norm2.weight            trainable=False
# base.features.denseblock4.denselayer4.norm2.bias              trainable=False
# base.features.denseblock4.denselayer4.conv2.weight            trainable=False
# base.features.denseblock4.denselayer5.norm1.weight            trainable=False
# base.features.denseblock4.denselayer5.norm1.bias              trainable=False
# base.features.denseblock4.denselayer5.conv1.weight            trainable=False
# base.features.denseblock4.denselayer5.norm2.weight            trainable=False
# base.features.denseblock4.denselayer5.norm2.bias              trainable=False
# base.features.denseblock4.denselayer5.conv2.weight            trainable=False
# base.features.denseblock4.denselayer6.norm1.weight            trainable=False
# base.features.denseblock4.denselayer6.norm1.bias              trainable=False
# base.features.denseblock4.denselayer6.conv1.weight            trainable=False
# base.features.denseblock4.denselayer6.norm2.weight            trainable=False
# base.features.denseblock4.denselayer6.norm2.bias              trainable=False
# base.features.denseblock4.denselayer6.conv2.weight            trainable=False
# base.features.denseblock4.denselayer7.norm1.weight            trainable=False
# base.features.denseblock4.denselayer7.norm1.bias              trainable=False
# base.features.denseblock4.denselayer7.conv1.weight            trainable=False
# base.features.denseblock4.denselayer7.norm2.weight            trainable=False
# base.features.denseblock4.denselayer7.norm2.bias              trainable=False
# base.features.denseblock4.denselayer7.conv2.weight            trainable=False
# base.features.denseblock4.denselayer8.norm1.weight            trainable=False
# base.features.denseblock4.denselayer8.norm1.bias              trainable=False
# base.features.denseblock4.denselayer8.conv1.weight            trainable=False
# base.features.denseblock4.denselayer8.norm2.weight            trainable=False
# base.features.denseblock4.denselayer8.norm2.bias              trainable=False
# base.features.denseblock4.denselayer8.conv2.weight            trainable=False
# base.features.denseblock4.denselayer9.norm1.weight            trainable=False
# base.features.denseblock4.denselayer9.norm1.bias              trainable=False
# base.features.denseblock4.denselayer9.conv1.weight            trainable=False
# base.features.denseblock4.denselayer9.norm2.weight            trainable=False
# base.features.denseblock4.denselayer9.norm2.bias              trainable=False
# base.features.denseblock4.denselayer9.conv2.weight            trainable=False
# base.features.denseblock4.denselayer10.norm1.weight           trainable=False
# base.features.denseblock4.denselayer10.norm1.bias             trainable=False
# base.features.denseblock4.denselayer10.conv1.weight           trainable=False
# base.features.denseblock4.denselayer10.norm2.weight           trainable=False
# base.features.denseblock4.denselayer10.norm2.bias             trainable=False
# base.features.denseblock4.denselayer10.conv2.weight           trainable=False
# base.features.denseblock4.denselayer11.norm1.weight           trainable=False
# base.features.denseblock4.denselayer11.norm1.bias             trainable=False
# base.features.denseblock4.denselayer11.conv1.weight           trainable=False
# base.features.denseblock4.denselayer11.norm2.weight           trainable=False
# base.features.denseblock4.denselayer11.norm2.bias             trainable=False
# base.features.denseblock4.denselayer11.conv2.weight           trainable=False
# base.features.denseblock4.denselayer12.norm1.weight           trainable=False
# base.features.denseblock4.denselayer12.norm1.bias             trainable=False
# base.features.denseblock4.denselayer12.conv1.weight           trainable=False
# base.features.denseblock4.denselayer12.norm2.weight           trainable=False
# base.features.denseblock4.denselayer12.norm2.bias             trainable=False
# base.features.denseblock4.denselayer12.conv2.weight           trainable=False
# base.features.denseblock4.denselayer13.norm1.weight           trainable=False
# base.features.denseblock4.denselayer13.norm1.bias             trainable=False
# base.features.denseblock4.denselayer13.conv1.weight           trainable=False
# base.features.denseblock4.denselayer13.norm2.weight           trainable=False
# base.features.denseblock4.denselayer13.norm2.bias             trainable=False
# base.features.denseblock4.denselayer13.conv2.weight           trainable=False
# base.features.denseblock4.denselayer14.norm1.weight           trainable=False
# base.features.denseblock4.denselayer14.norm1.bias             trainable=False
# base.features.denseblock4.denselayer14.conv1.weight           trainable=False
# base.features.denseblock4.denselayer14.norm2.weight           trainable=False
# base.features.denseblock4.denselayer14.norm2.bias             trainable=False
# base.features.denseblock4.denselayer14.conv2.weight           trainable=False
# base.features.denseblock4.denselayer15.norm1.weight           trainable=False
# base.features.denseblock4.denselayer15.norm1.bias             trainable=False
# base.features.denseblock4.denselayer15.conv1.weight           trainable=False
# base.features.denseblock4.denselayer15.norm2.weight           trainable=False
# base.features.denseblock4.denselayer15.norm2.bias             trainable=False
# base.features.denseblock4.denselayer15.conv2.weight           trainable=False
# base.features.denseblock4.denselayer16.norm1.weight           trainable=False
# base.features.denseblock4.denselayer16.norm1.bias             trainable=False
# base.features.denseblock4.denselayer16.conv1.weight           trainable=False
# base.features.denseblock4.denselayer16.norm2.weight           trainable=False
# base.features.denseblock4.denselayer16.norm2.bias             trainable=False
# base.features.denseblock4.denselayer16.conv2.weight           trainable=False
# base.features.norm5.weight                                    trainable=False
# base.features.norm5.bias                                      trainable=False
# base.classifier.weight                                        trainable=False
# base.classifier.bias                                          trainable=False
# classifier.weight                                             trainable=True
# classifier.bias                                               trainable=True

# %%
print("Classifier weight mean:", my_model.classifier.weight.mean().item())
print("Classifier bias mean:", my_model.classifier.bias.mean().item())
print("Classifier weight std:", my_model.classifier.weight.std().item())
# Out:
# Classifier weight mean: 0.09434664994478226
# Classifier bias mean: -0.7427027225494385
# Classifier weight std: 0.34683993458747864
